# %%
from pylab import *
import pandas as pd
from sklearn import datasets
# %matplotlib inline

# %% [markdown]
# # 1. Load log file

# %%
machine = 'patatrack02'


with open("../log/{}_toyDetector_200.log".format(machine)) as f:
    lines = f.readlines()
    
tbblabel = "CUPLATBB_2"
tbbnthread = "CPU TBB [10T]"

# %%
def getProf():
    HToD,DtoH,k1,k2,k3,k4,k5,memset = [],[],[],[],[],[],[],[]
    
    for line in lines:  
        wordsInLine = line.split("  ")

        if wordsInLine[-1] == "[CUDA memcpy HtoD]\n":
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            HToD.append(time)

        if wordsInLine[-1] == "[CUDA memcpy DtoH]\n":
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            DtoH.append(time)

        if wordsInLine[-1] == "cudaMemset\n":
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            memset.append(time)
            
        name = "kernel_compute_histogram"
        if wordsInLine[-1][:len(name)] == name:
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            k1.append(time)

        name = "kernel_compute_density"
        if wordsInLine[-1][:len(name)] == name:
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            k2.append(time)

        name = "kernel_compute_distanceToHigher"
        if wordsInLine[-1][:len(name)] == name:
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            k3.append(time)

        name = "kernel_find_clusters"
        if wordsInLine[-1][:len(name)] == name:
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            k4.append(time)

        name = "kernel_assign_clusters"
        if wordsInLine[-1][:len(name)] == name:
            word = wordsInLine[-8]
            time = float(word[:-2])
            if word[-2:] == "us":
                time /= 1000
            k5.append(time)
        
    prof = np.array([HToD,DtoH,memset,k1,k2,k3,k4,k5]).T
    return prof


compileStatus = 0
for l,thisline in enumerate(lines):

    if thisline == "running with CPU\n":
        compileStatus = 1
        times = []
    if thisline == "running with GPU\n":
        df = pd.DataFrame.from_records([times],columns=np.arange(1000,10001,1000),index=["CPU"])
        compileStatus = 2
        times = []
    if thisline == "running with GPU with nvprof\n":

        df = df.append(pd.DataFrame.from_records([times],columns=np.arange(1000,10001,1000),index=["GPUTotal"]))
        prof = getProf()
        df = df.append(pd.DataFrame.from_records([prof.reshape(10,8,-1)],columns=np.arange(1000,10001,1000),index=["GPUProf"]))
        
        compileStatus = 3
        times = []
    if thisline == "running with CUPLA CPU TBB nthreads= 1\n":
        compileStatus = 4
        times = []
    if thisline == "running with CUPLA CPU TBB nthreads= 10\n":
        df = df.append( pd.DataFrame.from_records([times],columns=np.arange(1000,10001,1000),index=["CUPLATBB_1"]))
        times = []
    if thisline == "running with CUPLA CPU TBB nthreads= 20\n":
        df = df.append( pd.DataFrame.from_records([times],columns=np.arange(1000,10001,1000),index=["CUPLATBB_2"]))
        times = []
    if thisline == "running with CUPLA CPU TBB nthreads= 40\n":
        df = df.append( pd.DataFrame.from_records([times],columns=np.arange(1000,10001,1000),index=["CUPLATBB_3"]))
        times = []       
    if l == len(lines)-1:
        df = df.append( pd.DataFrame.from_records([times],columns=np.arange(1000,10001,1000),index=["CUPLATBB_4"]))
        times = []  
        

    if thisline == "Start to run CLUE algorithm\n":
        time = []

    if thisline[0:13]=="Elapsed time:":
        if compileStatus in [1,4,5]:
            temp = [float(lines[l+nl][31:-3]) for nl in range(-5,0)] + [float(thisline[13:-3])]
            time.append(temp)
        if compileStatus in [2,6]:
            temp = [float(thisline[13:-3])]
            time.append(temp)


    if thisline == "Finished running CLUE algorithm\n":
        if compileStatus in [1,2,4]:
            time = np.array(time).T
            times.append(time)

# %% [markdown]
# # 2. Plot

# %%
cpu = np.array([df.loc["CPU",c][-1] for c in df.columns])
gpu = np.array([df.loc["GPUTotal",c][-1] for c in df.columns])
prof = np.array([df.loc["GPUProf",c][:,0] for c in df.columns]).T/200
cuplaTBB = np.array([df.loc[tbblabel,c][-1] for c in df.columns])

# %%
fig, axex = plt.subplots( 2,1, sharex=True, figsize=(9,6),facecolor='w',gridspec_kw={'height_ratios':[2,1]})
fig.subplots_adjust(hspace=0.08)

n = np.arange(1,11,1)

##########################
ax1= axex[0]
ax2 = ax1.twinx()

ax1.errorbar(n, gpu.mean(axis=1),yerr=gpu.std(axis=1), marker='o',linestyle='--',color='C2',label=r'GPU')
but = np.cumsum(prof,axis=0)
labels = [
          "-- cuda memcpy HToD",
          "-- cuda memcpy DToH",
          "-- cuda memset",
          "-- build tiles",
          "-- calculate density",
          "-- calculate separation",
          "-- promote seeds",
          "-- assign clusters",
          "-- other"
         ]

colors = ["C0", "C2", "C7","C3","C1","C5", "C6","C4", "0.8" ]


ax1.bar(n, prof[0],label= labels[0],width=0.4, facecolor=colors[0])
ax1.bar(n, prof[1], bottom=but[0],label= labels[1],width=0.4, facecolor=colors[1] )
for i in range(2,8):
    ax1.bar(n, prof[i], bottom=but[i-1],label= labels[i],width=0.7, facecolor=colors[i] )
other = gpu.mean(axis=1) - but[7]
ax1.bar(n, other, bottom=but[7],width=0.4,label= labels[8], facecolor=colors[8] )

ax1.set_ylim(0,16)
ax1.set_xlim(0,11)
ax1.grid(linestyle='--',alpha=0.5)
ax1.legend(fontsize=10)

ax1.set_ylabel("GPU Total Execution Time [ms]",fontsize=12,color="C2")
ax1.tick_params(axis='y', labelcolor="C2")
ax1.set_title("Intel Xeon Silver 4114 [40T] + NVIDIA Tesla V100",fontsize=12)

ax2.errorbar(n, cpu.mean(axis=1),yerr=cpu.std(axis=1), marker='o',linestyle=':',color="C0",label=r'CPU [1T]')
ax2.errorbar(n, cuplaTBB.mean(axis=1),yerr=cuplaTBB.std(axis=1), marker='s',linestyle=':',color="b",label=tbbnthread)
ax2.legend(fontsize=10,loc="upper center")
ax2.set_ylim(0,800)
ax2.tick_params(axis='y', labelcolor="C0")
ax2.set_ylabel("CPU Total Execution Time [ms]",fontsize=12,color="C0")

##########################
ax3 = axex[1]
speedup= cpu.mean(axis=1)/gpu.mean(axis=1)
ax3.plot(n, speedup, marker='o',linestyle=':',color="k",label='GPU vs. CPU [1T]')

for i in range(n.size):
    ax3.text(n[i]-0.2,speedup[i]/2.5,"{:2.0f}X".format(speedup[i]))
    

speedup= cpu.mean(axis=1)/cuplaTBB.mean(axis=1)
ax3.plot(n, speedup, marker='s',linestyle=':',color="k",label=tbbnthread + ' vs. CPU [1T]')
for i in range(n.size):
    ax3.text(n[i]-0.2,speedup[i]*1.5,"{:3.1f}X".format(speedup[i]))
    
ax3.set_xlabel(r"Number of Points per Layer [$10^3$]. Totally 100 layers.",fontsize=12)
ax3.legend(fontsize=10, loc="upper left")
ax3.set_ylabel("Speedup",fontsize=11,color="k")
ax3.set_ylim(1,800)
ax3.grid(linestyle='--',alpha=0.5)
ax3.set_yscale("log")

plt.savefig("../plots/Figure5_patatrack02.pdf")
plt.savefig("../plots/Figure5_patatrack02.png",dpi=400)

# %% [markdown]
# # fully decomsited

# %%
cpuMeans = np.array([df.loc["CPU",c].mean(axis=1) for c in df.columns]).T
cuplaTBBMeans = np.array([df.loc[tbblabel,c].mean(axis=1) for c in df.columns]).T

# %%
fig, axex = plt.subplots( 2,1, sharex=True, figsize=(8,6),facecolor='w',gridspec_kw={'height_ratios':[2,1]})
fig.subplots_adjust(hspace=0.08)

n = np.arange(1,11,1)

##########################
ax1 = axex[0]
ax2 = ax1.twinx()


labels = [
          "-- cuda memcpy HToD",
          "-- cuda memcpy DToH",
          "-- cuda memset",
          "-- build tiles",
          "-- calculate density",
          "-- calculate separation",
          "-- promote seeds",
          "-- assign clusters",
          "-- other"
         ]

colors = ["C0", "C2", "C7","C3","C1","C5", "C6","C4", "0.8" ]

ax2.errorbar(n, gpu.mean(axis=1),yerr=gpu.std(axis=1),xerr=np.c_[np.array([0]*10),np.array([0.3]*10)].T, marker='o',linestyle='--',color='C2',label=r'GPU')
but = np.cumsum(prof,axis=0)
ax2.bar(n+0.25, prof[0],label= labels[0],width=0.1, facecolor=colors[0])
ax2.bar(n+0.25, prof[1], bottom=but[0],label= labels[1], width=0.1, facecolor=colors[1] )
for i in range(2,8):
    ax2.bar(n+0.25, prof[i], bottom=but[i-1],label= labels[i],width=0.24, facecolor=colors[i] )
other = gpu.mean(axis=1) - but[7]
ax2.bar(n+0.25, other, bottom=but[7],width=0.1,label= labels[8], facecolor=colors[8] )

ax2.set_ylim(0,16)
ax2.set_xlim(0,11)
ax1.grid(linestyle='--',axis='y',alpha=0.5)
ax2.legend(fontsize=10)

ax2.set_ylabel("GPU Total Execution Time [ms]",fontsize=12,color="C2")
ax2.tick_params(axis='y', labelcolor="C2")
ax1.set_title("Intel Xeon Silver 4114 [40T] + NVIDIA Tesla V100",fontsize=12)

ax1.errorbar(n, cpu.mean(axis=1),yerr=cpu.std(axis=1), marker='o',linestyle=':',color="C0",label=r'CPU [1T]')
but = np.cumsum(cpuMeans,axis=0) 
for i in range(5):
    ax1.bar(n, cpuMeans[i], bottom=but[i]-cpuMeans[i],width=0.24, facecolor=colors[i+3] )
ax1.bar(n, cpuMeans[-1]-but[4], bottom=but[4],width=0.1, facecolor=colors[5+3] )

ax1.errorbar(n, cuplaTBB.mean(axis=1),yerr=cuplaTBB.std(axis=1),xerr=np.c_[np.array([0.3]*10),np.array([0]*10)].T, marker='s',linestyle=':',color="b",label=tbbnthread)
but = np.cumsum(cuplaTBBMeans,axis=0) 
for i in range(5):
    ax1.bar(n-0.25, cuplaTBBMeans[i], bottom=but[i]-cuplaTBBMeans[i],width=0.24, facecolor=colors[i+3] )
ax1.bar(n-0.25,  cuplaTBBMeans[-1]-but[4], bottom=but[4],width=0.1, facecolor=colors[5+3] )

    
ax1.legend(fontsize=10,loc="upper center")
ax1.set_ylim(0,800)
ax1.tick_params(axis='y', labelcolor="C0")
ax1.set_ylabel("CPU Total Execution Time [ms]",fontsize=12,color="C0")
for xx in range(12):
    ax1.axvline(xx-0.5,linestyle='--',c='grey',lw=0.5,alpha=0.5)

##########################
ax3 = axex[1]
speedup= cpu.mean(axis=1)/gpu.mean(axis=1)
ax3.plot(n, speedup, marker='o',linestyle=':',color="k",label='GPU vs. CPU [1T]')

for i in range(n.size):
    ax3.text(n[i]-0.2,speedup[i]/2.5,"{:2.0f}X".format(speedup[i]))
    

speedup= cpu.mean(axis=1)/cuplaTBB.mean(axis=1)
ax3.plot(n, speedup, marker='s',linestyle=':',color="k",label=tbbnthread + ' vs. CPU [1T]')
for i in range(n.size):
    ax3.text(n[i]-0.2,speedup[i]*1.5,"{:3.1f}X".format(speedup[i]))
    
ax3.set_xlabel(r"Number of Points per Layer [$10^3$]. Totally 100 layers.",fontsize=12)
ax3.legend(fontsize=10, loc="upper left")
ax3.set_ylabel("Speedup",fontsize=11,color="k")
ax3.set_ylim(1,800)
ax3.grid(linestyle='--',axis='y',alpha=0.5)
ax3.set_yscale("log")
ax3.set_xticks(n)
for xx in range(12):
    ax3.axvline(xx-0.5,linestyle='--',c='grey',lw=0.5,alpha=0.5)

plt.savefig("../plots/Figure5_patatrack02_1.pdf")
plt.savefig("../plots/Figure5_patatrack02_1.png",dpi=400)

# %% [markdown]
# # 3. Generate latex

# %%
latex = open('../log/patatrack02_toyDetector_decompose.tex','w') 

nexline = r"\\"
bold1 = r"\textbf{"
bold2 = r"}"
pm = r"$\pm$"
getother = np.array([-1,-1,-1,-1,-1,1])


for c in range(10):
    gpuProfMean = prof[:,c]
    
    meams = [df.loc["CPU",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_1",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_2",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_3",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_4",1000*(c+1)].mean(axis=1),
             df.loc["GPUTotal",1000*(c+1)].mean(axis=1)
            ]
    
    stds  = [df.loc["CPU",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_1",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_2",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_3",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_4",1000*(c+1)].std(axis=1),
             df.loc["GPUTotal",1000*(c+1)].std(axis=1)
            ]
    
    otherMeans = [df.loc["CPU",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_1",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_2",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_3",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_4",1000*(c+1)].T.dot(getother).mean(),
                  meams[5][-1]-gpuProfMean.sum()
                 ]
    
    otherstds = [df.loc["CPU",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_1",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_2",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_3",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_4",1000*(c+1)].T.dot(getother).std(),
                  0
                 ]
    
    
    
    latex.write( "    % {}\n".format(1000*(c+1)))
    latex.write(r"    \begin{tabular}{l|c|c|c}"+"\n")
    table = '''    \hline
    CLUE Step                                 & CPU [1T] (baseline)         & CPU TBB [16T]                         & GPU                       {} \hline
    build fixed-grid spatial index            & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    calculate local density                   & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    calculate nearest-higher and separation   & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    decide seeds/outliers, register followers & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    expand clusters                           & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {} \hline
    cuda memcpy, memset                       & --                          & --                                    & {:6.2f} ms, {:6.2f} ms      {} 
    other                                     & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms                 & {:6.2f} ms                 {} \hline
    {}TOTAL{} ({:5} points per layer)   & {}{:6.2f} {} {:5.2f} ms{} & {}{:6.2f} {} {:5.2f} ms ({:5.2f}x){} & {}{:6.2f} {} {:5.2f} ms ({:6.2f}x){}  {}
    \hline
    {} \n'''.format(nexline,
                   meams[0][0], pm, stds[0][0], meams[4][0], pm, stds[4][0],  meams[0][0]/meams[4][0],   gpuProfMean[3], meams[0][0]/gpuProfMean[3], nexline,
                   meams[0][1], pm, stds[0][1], meams[4][1], pm, stds[4][1],  meams[0][1]/meams[4][1],   gpuProfMean[4], meams[0][1]/gpuProfMean[4], nexline,
                   meams[0][2], pm, stds[0][2], meams[4][2], pm, stds[4][2],  meams[0][2]/meams[4][2],   gpuProfMean[5], meams[0][2]/gpuProfMean[5], nexline,
                   meams[0][3], pm, stds[0][3], meams[4][3], pm, stds[4][3],  meams[0][3]/meams[4][3],   gpuProfMean[6], meams[0][3]/gpuProfMean[6], nexline,
                   meams[0][4], pm, stds[0][4], meams[4][4], pm, stds[4][4],  meams[0][4]/meams[4][4],   gpuProfMean[7], meams[0][4]/gpuProfMean[7], nexline,
                   # cuda api
                   gpuProfMean[0]+gpuProfMean[1], gpuProfMean[2], nexline,
                   # other
                   otherMeans[0], pm, otherstds[0],   otherMeans[4],pm,otherstds[4],   otherMeans[5], nexline,
                   bold1,bold2, 1000*(c+1),
                   # total
                   bold1,meams[0][-1],pm,stds[0][-1],bold2, 
                   bold1,meams[4][-1],pm,stds[4][-1],meams[0][-1]/meams[4][-1],bold2, 
                   bold1,meams[5][-1],pm,stds[5][-1],meams[0][-1]/meams[5][-1],bold2, nexline,
                   "\multicolumn{4}{c}{}"
                  )
    latex.write(table)
    latex.write("    \end{tabular}\n    \linebreak\n\n\n")
latex.close()

# %% [markdown]
# # 4. More latex table

# %%
latex = open('../log/patatrack02_toyDetector_decompose_2.tex','w') 

nexline = r"\\"
bold1 = r"\textbf{"
bold2 = r"}"
pm = r"$\pm$"
getother = np.array([-1,-1,-1,-1,-1,1])


for c in range(10):
    gpuProfMean = prof[:,c]
    
    meams = [df.loc["CPU",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_1",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_2",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_3",1000*(c+1)].mean(axis=1),
             df.loc["CUPLATBB_4",1000*(c+1)].mean(axis=1),
             df.loc["GPUTotal",1000*(c+1)].mean(axis=1)
            ]
    
    stds  = [df.loc["CPU",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_1",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_2",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_3",1000*(c+1)].std(axis=1),
             df.loc["CUPLATBB_4",1000*(c+1)].std(axis=1),
             df.loc["GPUTotal",1000*(c+1)].std(axis=1)
            ]
    
    otherMeans = [df.loc["CPU",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_1",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_2",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_3",1000*(c+1)].T.dot(getother).mean(),
                  df.loc["CUPLATBB_4",1000*(c+1)].T.dot(getother).mean(),
                  meams[5][-1]-gpuProfMean.sum()
                 ]
    
    otherstds = [df.loc["CPU",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_1",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_2",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_3",1000*(c+1)].T.dot(getother).std(),
                  df.loc["CUPLATBB_4",1000*(c+1)].T.dot(getother).std(),
                  0
                 ]
    
    
    
    latex.write( "    % {}\n".format(1000*(c+1)))
    latex.write(r"    \scalebox{0.7}{\begin{tabular}{l|c|c|c|c|c|c}"+"\n")
    table = '''    \hline
    CLUE Step                                 & CPU [1T] (baseline)         & CPU TBB [1T]                          & CPU TBB [4T]                          & CPU TBB [8T]                          & CPU TBB [16T]                         & GPU                       {} \hline
    build fixed-grid spatial index            & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    calculate local density                   & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    calculate nearest-higher and separation   & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    decide seeds/outliers, register followers & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {}
    expand clusters                           & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} {} {:5.2f} ms ({:5.2f}x)        & {:6.2f} ms ({:6.2f}x)       {} \hline
    cuda memcpy, memset                       & --                          & --                                    & --                                    & --                                    & --                                    & {:6.2f} ms, {:6.2f} ms      {} 
    other                                     & {:6.2f} {} {:5.2f} ms       & {:6.2f} {} {:5.2f} ms                 & {:6.2f} {} {:5.2f} ms                 & {:6.2f} {} {:5.2f} ms                 & {:6.2f} {} {:5.2f} ms                 & {:6.2f} ms                 {} \hline
    {}TOTAL{} ({:5} points per layer)   & {}{:6.2f} {} {:5.2f} ms{} & {}{:6.2f} {} {:5.2f} ms ({:5.2f}x){} & {}{:6.2f} {} {:5.2f} ms ({:5.2f}x){} & {}{:6.2f} {} {:5.2f} ms ({:5.2f}x){} & {}{:6.2f} {} {:5.2f} ms ({:5.2f}x){} & {}{:6.2f} {} {:5.2f} ms ({:6.2f}x){}  {}
    \hline 
    {} \n'''.format(nexline,
                    meams[0][0], pm, stds[0][0], meams[1][0], pm, stds[1][0],  meams[0][0]/meams[1][0],   meams[2][0], pm, stds[2][0],  meams[0][0]/meams[2][0],   meams[3][0], pm, stds[3][0],  meams[0][0]/meams[3][0],   meams[4][0], pm, stds[4][0],  meams[0][0]/meams[4][0],   gpuProfMean[3], meams[0][0]/gpuProfMean[3], nexline,
                    meams[0][1], pm, stds[0][1], meams[1][1], pm, stds[1][1],  meams[0][1]/meams[1][1],   meams[2][1], pm, stds[2][1],  meams[0][1]/meams[2][1],   meams[3][1], pm, stds[3][1],  meams[0][1]/meams[3][1],   meams[4][1], pm, stds[4][1],  meams[0][1]/meams[4][1],   gpuProfMean[4], meams[0][1]/gpuProfMean[4], nexline,
                    meams[0][2], pm, stds[0][2], meams[1][2], pm, stds[1][2],  meams[0][2]/meams[1][2],   meams[2][2], pm, stds[2][2],  meams[0][2]/meams[2][2],   meams[3][2], pm, stds[3][2],  meams[0][2]/meams[3][2],   meams[4][2], pm, stds[4][2],  meams[0][2]/meams[4][2],   gpuProfMean[5], meams[0][2]/gpuProfMean[5], nexline,
                    meams[0][3], pm, stds[0][3], meams[1][3], pm, stds[1][3],  meams[0][3]/meams[1][3],   meams[2][3], pm, stds[2][3],  meams[0][3]/meams[2][3],   meams[3][3], pm, stds[3][3],  meams[0][3]/meams[3][3],   meams[4][3], pm, stds[4][3],  meams[0][3]/meams[4][3],   gpuProfMean[6], meams[0][3]/gpuProfMean[6], nexline,
                    meams[0][4], pm, stds[0][4], meams[1][4], pm, stds[1][4],  meams[0][4]/meams[1][4],   meams[2][4], pm, stds[2][4],  meams[0][4]/meams[2][4],   meams[3][4], pm, stds[3][4],  meams[0][4]/meams[3][4],   meams[4][4], pm, stds[4][4],  meams[0][4]/meams[4][4],   gpuProfMean[7], meams[0][4]/gpuProfMean[7], nexline,
                    # cuda api
                    gpuProfMean[0]+gpuProfMean[1], gpuProfMean[2], nexline,
                    # other
                    otherMeans[0], pm, otherstds[0],   otherMeans[1],pm,otherstds[1],   otherMeans[2],pm,otherstds[2],   otherMeans[3],pm,otherstds[3],   otherMeans[4],pm,otherstds[4],   otherMeans[5], nexline,
                    bold1,bold2, 1000*(c+1),
                    # total
                    bold1,meams[0][-1],pm,stds[0][-1],bold2, 
                    bold1,meams[1][-1],pm,stds[1][-1],meams[0][-1]/meams[1][-1],bold2,
                    bold1,meams[2][-1],pm,stds[2][-1],meams[0][-1]/meams[2][-1],bold2,
                    bold1,meams[3][-1],pm,stds[3][-1],meams[0][-1]/meams[3][-1],bold2,
                    bold1,meams[4][-1],pm,stds[4][-1],meams[0][-1]/meams[4][-1],bold2,
                    bold1,meams[5][-1],pm,stds[5][-1],meams[0][-1]/meams[5][-1],bold2, nexline,
                    "\multicolumn{4}{c}{}"
                  )
    latex.write(table)
    latex.write("    \end{tabular}}\n    \linebreak\n\n\n")
latex.close()

# %% [markdown]
# # 5. Plot stability

# %%
plt.figure(figsize=(14,6),facecolor='w')

plt.subplot(1,6,1)
for i in range(10):
    plt.plot(cpu[i])
plt.title("{} CPU [1T]".format(machine),fontsize=11)
plt.xlabel("number of trial run")
plt.ylabel("execution time [ms]")
plt.yticks(fontsize=8)


machine = "pttrk02"
tbblabel,tbbnthread = "CUPLATBB_1","CPU TBB [1T]"
cuplaTBB = np.array([df.loc[tbblabel,c][-1] for c in df.columns])
plt.subplot(1,6,2)
for i in range(10):
    plt.plot(cuplaTBB[i])
plt.title("{} {}".format(machine,tbbnthread),fontsize=11)
plt.xlabel("number of trial run")
plt.yticks(fontsize=8)

tbblabel,tbbnthread = "CUPLATBB_2","CPU TBB [10T]"
cuplaTBB = np.array([df.loc[tbblabel,c][-1] for c in df.columns])
plt.subplot(1,6,3)
for i in range(10):
    plt.plot(cuplaTBB[i])
plt.title("{} {}".format(machine,tbbnthread),fontsize=11)
plt.xlabel("number of trial run")
plt.yticks(fontsize=8)

tbblabel,tbbnthread = "CUPLATBB_3","CPU TBB [20T]"
cuplaTBB = np.array([df.loc[tbblabel,c][-1] for c in df.columns])
plt.subplot(1,6,4)
for i in range(10):
    plt.plot(cuplaTBB[i])
plt.title("{} {}".format(machine,tbbnthread),fontsize=11)
plt.xlabel("number of trial run")
plt.yticks(fontsize=8)

tbblabel,tbbnthread = "CUPLATBB_4","CPU TBB [40T]"
cuplaTBB = np.array([df.loc[tbblabel,c][-1] for c in df.columns])
plt.subplot(1,6,5)
for i in range(10):
    plt.plot(cuplaTBB[i])
plt.title("{} {}".format(machine,tbbnthread),fontsize=11)
plt.xlabel("number of trial run")
plt.yticks(fontsize=8)

    
plt.subplot(1,6,6)
for i in range(10):
    plt.plot(gpu[i],label="{}k/layer".format(i+1))
plt.title("{} GPU".format(machine),fontsize=11)
plt.xlabel("number of trial run")
plt.yticks(fontsize=8)

plt.savefig("../plots/addition_{}.pdf".format(machine))
plt.savefig("../plots/addition_{}.png".format(machine),dpi=400)
